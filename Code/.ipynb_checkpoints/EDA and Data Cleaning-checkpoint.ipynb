# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv("../datasets/all_stats")

# %%
data.head()
# Out:
#    Unnamed: 0  away_assist_percentage  away_assists  away_block_percentage  \
# 0           0                    77.8            21                    6.7
# 1           1                    54.3            19                    3.3
# 2           2                    47.1            16                    6.5
# 3           3                    56.4            22                    8.2
# 4           4                    65.1            28                    3.2
#
#    away_blocks  away_defensive_rating  away_defensive_rebound_percentage  \
# 0            4                  112.0                               73.3
# 1            2                  113.6                               70.3
# 2            4                   95.1                               79.5
# 3            5                  112.4                               71.7
# 4            2                  119.9                               78.9
#
#    away_defensive_rebounds  away_effective_field_goal_percentage  \
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                0
# away_assist_percentage    0
# away_assists              0
# away_block_percentage     0
# away_blocks               0
#                          ..
# losing_name               0
# pace                      0
# winner                    0
# winning_abbr              0
# winning_name              0
# Length: 83, dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'away_assist_percentage', 'away_assists',
#        'away_block_percentage', 'away_blocks', 'away_defensive_rating',
#        'away_defensive_rebound_percentage', 'away_defensive_rebounds',
#        'away_effective_field_goal_percentage', 'away_field_goal_attempts',
#        'away_field_goal_percentage', 'away_field_goals',
#        'away_free_throw_attempt_rate', 'away_free_throw_attempts',
#        'away_free_throw_percentage', 'away_free_throws', 'away_losses',
#        'away_minutes_played', 'away_offensive_rating',
#        'away_offensive_rebound_percentage', 'away_offensive_rebounds',
#        'away_personal_fouls', 'away_points', 'away_steal_percentage',
#        'away_steals', 'away_three_point_attempt_rate',
#        'away_three_point_field_goal_attempts',
#        'away_three_point_field_goal_percentage',
#        'away_three_point_field_goals', 'away_total_rebound_percentage',
#        'away_total_rebounds', 'away_true_shooting_percentage',
# ...

# %%
# since our box score method reads in duplicate sets for each game (one for each team), let's get rid of duplicate 
# and NaN values

data.dropna().drop_duplicates()
print(data.isnull().sum(axis=0).sort_values(ascending=False))
# Out:
# winning_name                         0
# away_offensive_rebounds              0
# away_points                          0
# away_steal_percentage                0
# away_steals                          0
#                                     ..
# home_offensive_rating                0
# home_offensive_rebound_percentage    0
# home_offensive_rebounds              0
# home_personal_fouls                  0
# Unnamed: 0                           0
# Length: 83, dtype: int64

# %%
# removing unneccesary columns

data.drop(['Unnamed: 0', 'date', 'location', 'losing_abbr', 'losing_name', 'winner', 'winning_abbr',
          'losing_abbr', 'winning_name', 'losing_name'], axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['away_assist_percentage', 'away_assists', 'away_block_percentage',
#        'away_blocks', 'away_defensive_rating',
#        'away_defensive_rebound_percentage', 'away_defensive_rebounds',
#        'away_effective_field_goal_percentage', 'away_field_goal_attempts',
#        'away_field_goal_percentage', 'away_field_goals',
#        'away_free_throw_attempt_rate', 'away_free_throw_attempts',
#        'away_free_throw_percentage', 'away_free_throws', 'away_losses',
#        'away_minutes_played', 'away_offensive_rating',
#        'away_offensive_rebound_percentage', 'away_offensive_rebounds',
#        'away_personal_fouls', 'away_points', 'away_steal_percentage',
#        'away_steals', 'away_three_point_attempt_rate',
#        'away_three_point_field_goal_attempts',
#        'away_three_point_field_goal_percentage',
#        'away_three_point_field_goals', 'away_total_rebound_percentage',
#        'away_total_rebounds', 'away_true_shooting_percentage',
# ...

# %%
data.to_csv('../datasets/box_scores_cleaned')
