# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the dataset (pre-cleaned)

df = pd.read_csv('../datasets/2020_team_stats.csv', index_col = None)

# %%
df.head()
# Out:
#    Unnamed: 0                  Team   W   L  PW  PL    MOV   SOS    SRS  \
# 0           0       Milwaukee Bucks  46   8  44  10  12.11 -1.27  10.84
# 1           1    Los Angeles Lakers  41  12  38  15   7.42  0.13   7.55
# 2           2        Boston Celtics  38  16  38  16   6.87 -0.84   6.03
# 3           3      Dallas Mavericks  33  22  37  18   5.98 -0.03   5.95
# 4           4  Los Angeles Clippers  37  18  37  18   5.62  0.14   5.76
#
#     ORtg  ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  OeFG%  OTOV%  DRB%  \
# 0  113.5  ...  0.421  0.586  0.556  12.6  20.9   0.197  0.485   12.1  81.3
# 1  113.6  ...  0.350  0.581  0.552  13.3  25.0   0.195  0.512   13.6  78.9
# 2  113.1  ...  0.380  0.570  0.532  12.2  23.6   0.205  0.508   13.7  77.8
# 3  117.6  ...  0.457  0.582  0.546  11.1  24.4   0.203  0.519   10.7  76.9
# 4  112.7  ...  0.363  0.570  0.529  12.8  24.1   0.227  0.504   12.4  77.3
#
#    OFT/FGA
# 0    0.171
# 1    0.200
# 2    0.212
# 3    0.178
# 4    0.210
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
#        'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'eFG%', 'TOV%', 'ORB%',
#        'FT/FGA', 'OeFG%', 'OTOV%', 'DRB%', 'OFT/FGA'],
#       dtype='object')

# %%
# check the datatypes out

df.dtypes
# Out:
# Unnamed: 0      int64
# Team           object
# W               int64
# L               int64
# PW              int64
# PL              int64
# MOV           float64
# SOS           float64
# SRS           float64
# ORtg          float64
# DRtg          float64
# NRtg          float64
# Pace          float64
# FTr           float64
# 3PAr          float64
# TS%           float64
# eFG%          float64
# TOV%          float64
# ORB%          float64
# FT/FGA        float64
# OeFG%         float64
# OTOV%         float64
# DRB%          float64
# OFT/FGA       float64
# dtype: object

# %%
df.drop(['Unnamed: 0', 'Team', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg', 'DRtg', '3PAr'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['W', 'L', 'NRtg', 'Pace', 'FTr', 'TS%', 'eFG%', 'TOV%', 'ORB%',
#        'FT/FGA', 'OeFG%', 'OTOV%', 'DRB%', 'OFT/FGA'],
#       dtype='object')

# %%
df.corr()
# Out:
#                 W         L      NRtg      Pace       FTr       TS%      eFG%  \
# W        1.000000 -0.995258  0.965187  0.060291  0.249138  0.745552  0.762902
# L       -0.995258  1.000000 -0.961521 -0.080234 -0.258095 -0.745287 -0.764639
# NRtg     0.965187 -0.961521  1.000000  0.119178  0.314199  0.779800  0.782660
# Pace     0.060291 -0.080234  0.119178  1.000000  0.277366  0.235733  0.199100
# FTr      0.249138 -0.258095  0.314199  0.277366  1.000000  0.363854  0.201053
# TS%      0.745552 -0.745287  0.779800  0.235733  0.363854  1.000000  0.963030
# eFG%     0.762902 -0.764639  0.782660  0.199100  0.201053  0.963030  1.000000
# TOV%    -0.290227  0.280840 -0.334633  0.109209  0.039366 -0.132264 -0.075853
# ORB%    -0.038506  0.029348 -0.058959 -0.124052 -0.135601 -0.278398 -0.160283
# FT/FGA   0.228730 -0.229946  0.292264  0.252981  0.915842  0.426547  0.196410
# OeFG%   -0.873461  0.863457 -0.878864 -0.176316 -0.244369 -0.584862 -0.609002
# OTOV%   -0.116888  0.117895 -0.106965  0.001722 -0.089021 -0.305748 -0.330432
# DRB%     0.465879 -0.483903  0.485130  0.019638  0.173678  0.341653  0.403824
# OFT/FGA -0.183512  0.181191 -0.158591  0.388456 -0.060531 -0.056255 -0.061843
#
#              TOV%      ORB%    FT/FGA     OeFG%     OTOV%      DRB%   OFT/FGA
# W       -0.290227 -0.038506  0.228730 -0.873461 -0.116888  0.465879 -0.183512
# L        0.280840  0.029348 -0.229946  0.863457  0.117895 -0.483903  0.181191
# NRtg    -0.334633 -0.058959  0.292264 -0.878864 -0.106965  0.485130 -0.158591
# Pace     0.109209 -0.124052  0.252981 -0.176316  0.001722  0.019638  0.388456
# FTr      0.039366 -0.135601  0.915842 -0.244369 -0.089021  0.173678 -0.060531
# TS%     -0.132264 -0.278398  0.426547 -0.584862 -0.305748  0.341653 -0.056255
# eFG%    -0.075853 -0.160283  0.196410 -0.609002 -0.330432  0.403824 -0.061843
# TOV%     1.000000  0.128587 -0.097492  0.219949  0.183808  0.005191  0.116389
# ORB%     0.128587  1.000000 -0.334972  0.119722 -0.001335 -0.059630  0.047214
# FT/FGA  -0.097492 -0.334972  1.000000 -0.184462 -0.049685  0.029063 -0.042903
# OeFG%    0.219949  0.119722 -0.184462  1.000000  0.218704 -0.450988  0.163435
# OTOV%    0.183808 -0.001335 -0.049685  0.218704  1.000000 -0.233992  0.377262
# DRB%     0.005191 -0.059630  0.029063 -0.450988 -0.233992  1.000000 -0.111557
# OFT/FGA  0.116389  0.047214 -0.042903  0.163435  0.377262 -0.111557  1.000000

# %%
# looking at all of the numeric features (above) to see if there is a linear correlation
# between the feature and team wins


fig = plt.figure(figsize=(15,50))

for i, col in enumerate(df[1:]):
    fig.add_subplot(13, 3, 1 + i)
    plt.scatter(df[col], df['W'])
    plt.xlabel(col)
    plt.ylabel('Wins')
fig.tight_layout()
fig.show()
# Out:
# /Users/dylanblough/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]

# %%
df.to_csv('../datasets/2020_team_stats_clean.csv')

# %% [markdown]
# ## Conclusions
#
# Looking at this data it looks like the strongest positive correlations to wins in the NBA involve higher offensive shooting percentages, and negative correlation to wins factor in when the opposing team shoots well. As you would expect, Net Rating is very linearly correlated with number of wins as the "better" teams are much more likely to win games.
#
# An interesting outlier can be found in the "Pace" scatter plot where the Milwaukee Bucks not only lead the league in pace, but also have the most wins. Another interesting outlier can be found in the Offensive Rating plot where we can see that despite their high offensive rating, the Boston Celtics have underperformed their number of wins.
#
# Most importantly for modeling we clearly visually see the importance of the 4 (really 8 factoring in two-way play) Factors we will be using for our modeling: overall scoring efficiency, free throw shooting, turnover percentage, and rebounding.
#
# Additional EDA steps will include be further research into incorporating rest days into the final model as star players taking games off strongly affects the outcome of the game.
